# %% [markdown]
# # QUESTION1
# `Re'em`
# <span style="color: red;">Mor</span>

# %% [markdown]
# ## QUESTION2
#
# **052-6775754**
#
# ***Tziley Hanina 5, Tel Aviv***

# %% [markdown]
# ## QUESTION3
#
# The pyramid
#
# <pre>
#  |
#      |
#          |
#              |
#                  |
#
# </pre>

# %% [markdown]
# ### QUESTION4
#
# The Pythagorean Theorem:
#
# $
# \underline{a^2 + b^2 = c^2}
# $

# %%
# QUESTION5

x = 3
y = 3.141
AREA = y * x ** 2

print("x =", x)
print("y =", y)
print("AREA =", AREA)

print("type of x =", type(x))
print("type of y =", type(y))
print("type of AREA =", type(AREA))
# Out:
# x = 3
# y = 3.141
# AREA = 28.269
# type of x = <class 'int'>
# type of y = <class 'float'>
# type of AREA = <class 'float'>

# %%
# QUESTION6

print(AREA // 4 <= 7)
print(AREA / 4 < 7)
print(not AREA / 4 < 7 and AREA // 4 <= 7)
# Out:
# True
# False
# True

# %%
# QUESTION7

str_name = "Reem Mor"

print(str_name[::2])
print(str_name[1::2])
# Out:
# Re o
# emMr

# %%
# QUESTION8

a = "#####"
b = "*****"
c = "Reem Mor"

result = a + c + b
space_index = c.find(" ")

first_name = c[:space_index]
last_name = c[space_index + 1:]

print(result)
print(f"Length of first name: {len(first_name)}\nLength of last name: {len(last_name)}")
# Out:
# #####Reem Mor*****
# Length of first name: 4
# Length of last name: 3

# %%
# QUESTION9

import matplotlib.pyplot as plt
from matplotlib.patches import Circle

fig, ax = plt.subplots()

circle1 = Circle((1, 1), 1, color="red")
circle2 = Circle((3, 1), 1, color="red")

ax.add_patch(circle1)
ax.add_patch(circle2)

ax.set_aspect('equal', adjustable='box')
ax.set_xlim(0, 4)
ax.set_ylim(0, 2)
ax.axis('on')

plt.show()
